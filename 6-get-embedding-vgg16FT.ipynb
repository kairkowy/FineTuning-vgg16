# %%
from keras.preprocessing import image
import keras,os,tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt

test_dir = 'data/test/'
test_img = '1.jpg'
#test_img = '10jpg'
#test_img = '2.jpg'
#test_img = '3.jpg'
#test_img = '4.jpg'
#test_img = '5.jpg'

img = image.load_img(test_dir+test_img,target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis=0)

# extract prefered layer information
from keras.models import load_model
model = load_model("repo/tun_vgg16_2a2.keras")
model.summary()

print(model.layers[22].get_config())

## extract all layers details information
#for layer in model.layers:
#    weights = layer.get_weights()
#    configs = layer.get_config()
#    print(configs)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 150, 150, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 150, 150, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 75, 75, 128)    │        73,856 │
# ...

# %%
# 모델 로딩, 임메딩 레이어 불로오기

embed = model.get_layer(index=22)

# 임베딩 출력

vector = embed(img)
print(vector)
# Out:
# tf.Tensor(
# [[[[ 41  68  98]
#    [ 37  63  98]
#    [ 40  66 103]
#    ...
#    [ 84 117 214]
#    [ 71 106 200]
#    [ 47  84 172]]
#
#   [[ 44  71 101]
#    [ 38  64  99]
#    [ 33  59  96]
#    ...
#    [ 85 115 213]
#    [ 70 103 198]
#    [ 48  82 171]]
#
#   [[ 40  67  97]
#    [ 30  56  91]
#    [ 35  61  98]
#    ...
#    [ 88 113 213]
#    [ 74 102 199]
#    [ 50  81 172]]
#
#   ...
#
#   [[172 176 187]
#    [181 185 197]
#    [181 185 197]
#    ...
#    [147 144 125]
#    [148 141 122]
#    [125 117  94]]
#
#   [[156 160 169]
#    [180 184 193]
#    [186 190 201]
#    ...
#    [105 106  90]
#    [ 89  88  67]
#    [111 109  84]]
#
#   [[168 172 173]
#    [172 175 180]
#    [184 187 196]
#    ...
#    [168 159 154]
#    [116 107  90]
#    [108  97  75]]]], shape=(1, 224, 224, 3), dtype=uint8)
